# %% [markdown]
# <a href="https://colab.research.google.com/github/adorable827/Data_Analysis/blob/main/9_LinearEquation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Linear Equation
# 선형 방정식 (일차 방정식)
#
# #_**y = a*x + b**_
#
# ### where
# ### a & b are _constants상수_ (or _coefficient계수_). The constant '**a**' is referred as a '<font color = 'blue'> **slope** </font>.' The consonat '**b**' is referred as an '<font color = 'blue'> **intercept** </font>.'
#
#
#
# # 🎈 **About the constant '<font color = 'red'>a</font>'**
# # **y = b + <font color = 'red'> a</font>*x**
#
# - ### Varying the value of a slope (aka. a): positive values for Rising 📈 vs. negative values for Falling 📉
#
#
#
# # 🎈 **About the constant '<font color = 'brown'>b</font>'**
# # **y =  <font color = 'brown'> b</font> + a*x**
# >
# - ### If b > 0, the graph intersects with the y-axis above the origin.
# - ### If b < 0, the graph intersects with the y-axis below the origin.
# - ### If b = 0, the graph intersects with the y-axis at the origin.
#
#     > <font color = 'brown'> The term "origin" refers to the point (0,0) on the Cartesian coordinate plane. "origin"이란 카테시안 좌표 평면 상의 (0,0) 지점

# %% [markdown]
# ## 1️⃣ If a > 0 and b > 0; a = 3 and b 2

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 100) #'x' will be an arry containing 100 values ranging from -10 to 10

a = 3
b = 2

y = b + a * x

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph with a > 0 and b > 0')
plt.grid(True)
#plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the range of x values
x = np.linspace(-10, 10, 100) #'x' will be an arry containing 100 values ranging from -10 to 10

# Define parameters
a = 3
b = 2

# Calculate y values
y = b + a * x

# Plot the graph
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph with a > 0 and b > 0')
plt.grid(True)
plt.show()

# %% [markdown]
# #2️⃣ a > 0 and b < 0; a = 3, b = -2

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-15, 15, 100)

a = 3
b = -2

y = b + a * x

plt.plot(x, y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Graph with a > 0 and b < 0')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the range of x values
x = np.linspace(-10, 10, 100)

# Define parameters
a = 3
b = -2

# Calculate y values
y = b + a * x

# Plot the graph
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph with a > 0 and b < 0')
plt.grid(True)
plt.show()

# %% [markdown]
# #3️⃣ a > 0 and b = 0; a = 3, b = 0

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-20, 20, 100)

a = 3
b = 0

y = b + a * x

plt.plot(x, y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Graph with a > 0 and b = 0')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the range of x values
x = np.linspace(-10, 10, 100)

# Define parameters
a = 3
b = 0

# Calculate y values
y = b + a * x

# Plot the graph
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph with a > 0 and b = 0')
plt.grid(True)
plt.show()

# %% [markdown]
# ##4️⃣ a < 0 and b > 0

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-40, 40, 100)

a = -3
b = 2

y = b + a * x

plt.plot(x, y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Graph with a < 0 and b > 0')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the range of x values
x = np.linspace(-10, 10, 100)

# Define parameters
a = -3
b = 2

# Calculate y values
y = b + a * x

# Plot the graph
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph with a < 0 and b > 0')
plt.grid(True)
plt.show()

# %% [markdown]
# ##5️⃣ a < 0 and b = 0; a = -3, b = 0

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-30,10,100)

a = -3
b = 0

y = b + a * x

plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Graph with a < 0 and b = 0')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the range of x values
x = np.linspace(-10, 10, 100)

# Define parameters
a = -3
b = 0

# Calculate y values
y = b + a * x

# Plot the graph
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph with a < 0 and b = 0')
plt.grid(True)
plt.show()

# %% [markdown]
# ##6️⃣  a < 0 and b < 0; a = -3, b = -2

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-20, 30, 100)

a = -3
b = -2

y = b + a * x

plt.plot(x, y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Graph with a < 0 and b < 0')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the range of x values
x = np.linspace(-10, 10, 100)

# Define parameters
a = -3
b = -2

# Calculate y values
y = b + a * x

# Plot the graph
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph with a < 0 and b < 0')
plt.grid(True)
plt.show()
